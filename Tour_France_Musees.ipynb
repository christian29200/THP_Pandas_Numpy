# %% [markdown]
# # Importation des librairies

# %%
import pandas as pd

# %%
data1 = pd.read_csv("./data/liste-des-musees-de-france-2021.csv",encoding='latin-1', sep = ';')

# %%
data1
# Out:
#           osm_id                                  name number  \
# 0     4540234591                               3 bis f    109
# 1     4388745689                      A casa di Losari    NaN
# 2     4426176194                      À l'homme volant     35
# 3     7652598615           Abbadiale - Maison des arts    NaN
# 4      121580330                                Abbaye    NaN
# ...          ...                                   ...    ...
# 3779  1348524503                    Vivarium du Moulin    NaN
# 3780   577287841  Voyage au Temps des impressionnistes    NaN
# 3781   145062184              Wines and Spirits Museum    NaN
# 3782    82988725                              Xanxotea    NaN
# 3783   277107550      Xylotheque - Kiosque Pedagogique    NaN
#
#                           street  postal_code              city country  \
# 0     Avenue du Petit Barthélémy      13617.0   Aix-en-Provence  France
# 1                           T 30      20226.0         Belgodère  France
# ...

# %% [markdown]
# # Importation des données

# %%
data1 = pd.read_csv("./data/liste-des-musees-de-france-2021.csv", sep = ';', encoding='latin-1', error_bad_lines=False)
data2 = pd.read_csv("./data/liste-des-musees-de-nouvelle-caledonie-2021.csv", sep = ';', encoding='latin-1', error_bad_lines=False)
data3 = pd.read_csv("./data/liste-des-musees-de-polynesie-francaise-2021.csv", sep = ';',encoding='latin-1', error_bad_lines=False)
data4 = pd.read_csv("./data/liste-des-musees-de-wallis-et-futuna-2021.csv", encoding='latin-1', sep = ';',error_bad_lines=False)
# Out:
# /Users/mvogo/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 5: expected 2 fields, saw 3\nSkipping line 6: expected 2 fields, saw 3\n'
# b'Skipping line 6: expected 3 fields, saw 4\nSkipping line 7: expected 3 fields, saw 4\nSkipping line 9: expected 3 fields, saw 4\n'

# %% [markdown]
# # Exploration des données

# %%
# Les premières features
data1.head()
# Out:
#        osm_id                         name number                      street  \
# 0  4540234591                      3 bis f    109  Avenue du Petit Barthélémy
# 1  4388745689             A casa di Losari    NaN                        T 30
# 2  4426176194             À l'homme volant     35                  Grande Rue
# 3  7652598615  Abbadiale - Maison des arts    NaN              Rue du Gabizos
# 4   121580330                       Abbaye    NaN             Rue de l'Abbaye
#
#    postal_code              city country country_code        lat       lon  \
# 0      13617.0   Aix-en-Provence  France           fr  43.521207  5.439875
# 1      20226.0         Belgodère  France           fr  42.638732  9.007660
# 2      72300.0  Sablé-sur-Sarthe  France           fr  47.839656 -0.334043
# 3      65400.0  Arras-en-Lavedan  France           fr  42.990826 -0.128057
# 4      39210.0    Château-Chalon  France           fr  46.753866  5.624296
#
# ...

# %%
# Les 5 dernières features
data1.tail()
# Out:
#           osm_id                                  name number  \
# 3779  1348524503                    Vivarium du Moulin    NaN
# 3780   577287841  Voyage au Temps des impressionnistes    NaN
# 3781   145062184              Wines and Spirits Museum    NaN
# 3782    82988725                              Xanxotea    NaN
# 3783   277107550      Xylotheque - Kiosque Pedagogique    NaN
#
#                        street  postal_code              city country  \
# 3779           Rue Principale      68610.0  Thann-Guebwiller  France
# 3780              Rue de Léry      95430.0   Auvers-sur-Oise  France
# 3781       Corniche Bonaparte      83150.0            Bandol  France
# 3782                 La Place      64240.0          Isturits  France
# 3783  Impasse de la Haie Vive      45590.0  Saint-Cyr-en-Val  France
#
#      country_code        lat       lon                   website email  phone  \
# 3779           fr  47.942258  7.149613                       NaN   NaN    NaN
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3784 entries, 0 to 3783
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   osm_id        3784 non-null   int64
#  1   name          3784 non-null   object
#  2   number        743 non-null    object
#  3   street        3771 non-null   object
#  4   postal_code   3728 non-null   float64
#  5   city          3782 non-null   object
#  6   country       3784 non-null   object
#  7   country_code  3784 non-null   object
#  8   lat           3784 non-null   float64
#  9   lon           3784 non-null   float64
#  10  website       1636 non-null   object
#  11  email         301 non-null    object
#  12  phone         1211 non-null   float64
#  13  fax           0 non-null      float64
#  14  tags          3782 non-null   object
#  15  description   226 non-null    object
#  16  date_added    3775 non-null   object
#  17  wikidata      1147 non-null   object
# ...

# %%
data1.describe()
# Out:
#              osm_id    postal_code          lat          lon         phone  \
# count  3.784000e+03    3728.000000  3784.000000  3784.000000  1.211000e+03
# mean   2.193306e+09   48499.273069    46.531075     2.724237  3.637847e+10
# std    2.521168e+09   27982.341434     2.234572     2.897485  9.501361e+10
# min    5.107373e+06    1000.000000    41.498794    -5.129406  8.250029e+08
# 25%    1.451896e+08   25582.500000    44.542494     0.570318  3.325117e+10
# 50%    8.226927e+08   49730.000000    46.513252     2.563655  3.338552e+10
# 75%    3.982632e+09   71570.000000    48.639156     4.984839  3.349082e+10
# max    8.394269e+09  590007.000000    51.053756     9.488302  3.320256e+12
#
#        fax
# count  0.0
# mean   NaN
# std    NaN
# min    NaN
# 25%    NaN
# 50%    NaN
# 75%    NaN
# max    NaN

# %%
data1.count()
# Out:
# osm_id          3784
# name            3784
# number           743
# street          3771
# postal_code     3728
# city            3782
# country         3784
# country_code    3784
# lat             3784
# lon             3784
# website         1636
# email            301
# phone           1211
# fax                0
# tags            3782
# description      226
# date_added      3775
# wikidata        1147
# dtype: int64

# %%
data1.columns
# Out:
# Index(['osm_id', 'name', 'number', 'street', 'postal_code', 'city', 'country',
#        'country_code', 'lat', 'lon', 'website', 'email', 'phone', 'fax',
#        'tags', 'description', 'date_added', 'wikidata'],
#       dtype='object')

# %%
#Combien y-a-t-il de musées en France métropolitaine ?
data1['osm_id'].count()
# Out:
# 3784

# %% [raw]
# Je compte le nombre d'identifiant musée par "osm_id" car ils sont uniques pour détéerminer le nombre de musées en France métropolitaine. Il y a donc 3784 musées.

# %%
# Dans quelle(s) ville(s) y-a-t-il de plus de musées ?
data1.groupby("city").count().sort_values(by='osm_id', ascending=False)
# Out:
#                    osm_id  name  number  street  postal_code  country  \
# city
# Paris                 175   175      70     174          171      175
# Lyon                   33    33       5      33           32       33
# Marseille              28    28       9      28           28       28
# Grenoble               22    22       9      22           22       22
# Toulouse               20    20       9      20           20       20
# ...                   ...   ...     ...     ...          ...      ...
# La Chaise-Dieu          1     1       0       1            1        1
# La Celle                1     1       0       1            1        1
# La Cassagne             1     1       0       1            1        1
# La Cadière-d'Azur       1     1       1       1            1        1
# Île-de-Sein             1     1       0       1            1        1
#
#                    country_code  lat  lon  website  email  phone  fax  tags  \
# city
# ...

# %%
# Quel est le nombre moyen de musées par ville ?
data1.groupby("city").count().mean()
# Out:
# osm_id          1.647930
# name            1.647930
# number          0.323747
# street          1.642266
# postal_code     1.623529
# country         1.647930
# country_code    1.647930
# lat             1.647930
# lon             1.647930
# website         0.712854
# email           0.131155
# phone           0.527669
# fax             0.000000
# tags            1.647059
# description     0.098475
# date_added      1.644009
# wikidata        0.499346
# dtype: float64

# %%
# Quel est le nombre médian de musées par ville ?
data1.groupby("city").count().median()
# Out:
# osm_id          1.0
# name            1.0
# number          0.0
# street          1.0
# postal_code     1.0
# country         1.0
# country_code    1.0
# lat             1.0
# lon             1.0
# website         0.0
# email           0.0
# phone           0.0
# fax             0.0
# tags            1.0
# description     0.0
# date_added      1.0
# wikidata        0.0
# dtype: float64

# %%
# Comment sont répartis les musées par type (en pourcentage) ?

# %%
# Combien y-a-t-il de musées dont le nom commence par "Château" ?
data1['name'].str.startswith("Château").value_counts()
# Out:
# False    3727
# True       57
# Name: name, dtype: int64

# %%
# Pour combien de musées dispose-t-on de l'adresse du site web ?
data1['website'].count()
# Out:
# 1636

# %%
# Quel département français possède le plus de musées sur son territoire ?
data1['postal_code']
# Out:
# pandas.core.series.Series

# %%
# Quel département français possède le moins de musées sur son territoire ?
data1['']

# %%
# Combien de musées ont "Napoléon" dans leur nom ?
data1['name'].str.contains("Napoléon").value_counts()
# Out:
# False    3780
# True        4
# Name: name, dtype: int64
